# %% [markdown]
# ### statement:
# Fetch the names of the character played by Tom Cruise in the movies:
# Top Gun

# %% [raw]
# Mission: Impossible - Fallout
# Minority Report
# Edge of Tomorrow

# %%
import requests 
api_key = "e226f4a5f5bace766952aa0d17182959" 
api_link = "https://api.themoviedb.org/3" 
params = {'query':"Tom Cruise", 'api_key':api_key} 
header = {'Accept': 'application/json'} 
response = requests.get(api_link + "/search/person", headers = header, params=params)
data = response.json()
ID = data['results'][0]['id']

# %%
param2 = {'api_key':api_key}
response = requests.get(api_link + "/person/"+str(ID)+"/movie_credits", headers = header, params=param2)
data = response.json()
data = data['cast']
for i in data:
    if i.get('original_title') == 'Top Gun':
        print(i.get('character'))
for i in data:
    if i.get('original_title') == 'Mission: Impossible - Fallout':
        print(i.get('character'))
for i in data:
    if i.get('original_title') == 'Minority Report':
        print(i.get('character'))
for i in data:
    if i.get('original_title') == 'Edge of Tomorrow':
        print(i.get('character'))
# Out:
# Lt. Pete 'Maverick' Mitchell
# Ethan Hunt
# Chief John Anderton
# Cage

# %%
import requests 
api_key = "e226f4a5f5bace766952aa0d17182959" 
api_link = "https://api.themoviedb.org/3" 
params = {'query':"Tom Cruise", 'api_key':api_key} 
header = {'Accept': 'application/json'} 
response = requests.get(api_link + "/search/person", headers = header, params=params)
data = response.json()
ID = data['results'][0]['id']

param2 = {'api_key':api_key}
response = requests.get(api_link + "/person/"+str(ID)+"/movie_credits", headers = header, params=param2)
data2 = response.json()
result = data2.get('cast')

for cast in result:
    if cast.get('original_title') == 'Top Gun':
        print(cast.get('character'))
for cast in result:
    if cast.get('original_title') == 'Mission: Impossible - Fallout':
        print(cast.get('character'))
for cast in result:
    if cast.get('original_title') == 'Minority Report':
        print(cast.get('character'))
for cast in result:
    if cast.get('original_title') == 'Edge of Tomorrow':
        print(cast.get('character'))
# Out:
# Lt. Pete 'Maverick' Mitchell
# Ethan Hunt
# Chief John Anderton
# Cage

# %% [markdown]
# ### statement:
# Did James McAvoy play a role in the movie Deadpool 2. Print Yes or No.

# %%
import requests 
api_key = "e226f4a5f5bace766952aa0d17182959" 
api_link = "https://api.themoviedb.org/3" 
params = {'query':"James McAvoy", 'api_key':api_key} 
header = {'Accept': 'application/json'} 
response = requests.get(api_link + "/search/person", headers = header, params=params)
data = response.json()
ID = data['results'][0]['id']

# %%
response = requests.get(api_link + "/person/"+str(ID)+"/movie_credits", headers = header, params=params)
data = response.json()
data = data['cast']
ans = False
for i in data:
    if i.get('title') == 'Deadpool 2':
        ans = True
if ans :
    print('Yes')
else:
    print('No')
# Out:
# Yes

# %% [markdown]
# ### statement:
# Using the result obtained in previous question, find out if James McAvoy was credited for his role in movie Deadpool 2. Print Yes or No.

# %%
import requests 
api_key = "e226f4a5f5bace766952aa0d17182959" 
api_link = "https://api.themoviedb.org/3" 
params = {'query':"James McAvoy", 'api_key':api_key} 
header = {'Accept': 'application/json'} 
response = requests.get(api_link + "/search/person", headers = header, params=params)
data = response.json()
ID = data['results'][0]['id']

# %%
response = requests.get(api_link + "/person/"+str(ID)+"/movie_credits", headers = header, params=params)
data = response.json()
data = data['cast']
ans = False
for i in data:
    if i.get('title') == 'Deadpool 2':
        print(i)
# Out:
# {'title': 'Deadpool 2', 'adult': False, 'backdrop_path': '/3P52oz9HPQWxcwHOwxtyrVV1LKi.jpg', 'genre_ids': [28, 35, 12], 'original_language': 'en', 'original_title': 'Deadpool 2', 'poster_path': '/to0spRl1CMDvyUbOnbb4fTk3VAd.jpg', 'vote_count': 13983, 'video': False, 'id': 383498, 'vote_average': 7.5, 'overview': "Wisecracking mercenary Deadpool battles the evil and powerful Cable and other bad guys to save a boy's life.", 'release_date': '2018-05-10', 'popularity': 121.677, 'character': 'Charles Xavier (uncredited)', 'credit_id': '5dff991126dac1001762a68f', 'order': 62}

# %% [markdown]
# ### statement:
# Fetch the overview of the TV Show "FRIENDS" using TMDb API.

# %%
import requests 
api_key = "e226f4a5f5bace766952aa0d17182959" 
api_link = "https://api.themoviedb.org/3" 
params = {'query':"FRIENDS", 'api_key':api_key} 
header = {'Accept': 'application/json'} 
response = requests.get(api_link + "/search/tv", headers = header, params=params)
data = response.json()
data = data['results']
print(data[0]['overview'])
# Out:
# Friends is an American television sitcom created by David Crane and Marta Kauffman, which aired on NBC from September 22, 1994, to May 6, 2004, lasting ten seasons. With an ensemble cast starring Jennifer Aniston, Courteney Cox, Lisa Kudrow, Matt LeBlanc, Matthew Perry and David Schwimmer, the show revolves around six friends in their 20s and 30s who live in Manhattan, New York City. The series was produced by Bright/Kauffman/Crane Productions, in association with Warner Bros. Television. The original executive producers were Kevin S. Bright, Kauffman, and Crane.

# %% [markdown]
# ### statement :
# Fetch the name and air date of S06E05 of the TV Show 'The Big Bang Theory' from TMDb API.

# %%
import requests 
api_key = "e226f4a5f5bace766952aa0d17182959" 
api_link = "https://api.themoviedb.org/3" 
params = {'query':"The Big Bang Theory", 'api_key':api_key} 
header = {'Accept': 'application/json'} 
response = requests.get(api_link + "/search/tv", headers = header, params=params)
data = response.json()
data = data['results'][0]
ID = data['id']

# %%
response = requests.get(api_link + "/tv/1418/season/06/episode/05", headers = header, params=params)
data = response.json()
date = data['air_date']
name = data['name']
print(name+' - '+date)
# Out:
# The Holographic Excitation - 2012-10-25

# %% [markdown]
# ### statement :
# Fetch the trending TV Shows from the TMDb API and print the taglines of the top 5 shows. If there is no tagline, print 'Empty' instead

# %%
import requests 
api_key = "e226f4a5f5bace766952aa0d17182959" 
api_link = "https://api.themoviedb.org/3" 
params = { 'api_key':api_key} 
header = {'Accept': 'application/json'} 
response = requests.get(api_link + "/trending/tv/week", headers = header, params=params)
data = response.json()
iD = []
for i in range(5):
#     print(data['results'][i])
    ID = data['results'][i]['id']
    iD.append(ID)
for ID in iD:
    response = requests.get(api_link + "/tv/"+str(ID), headers = header, params=params)
    data1 = response.json()
    if data1.get('tagline') != "":
        print(data1.get('tagline'))
    else:
        print('Empty')
# Out:
# This holiday season, the best gifts come with a bow.
# 45.6 billion won is child's play.
# Empty
# Empty
# Your time is up.

# %% [markdown]
# ### statement :
# Print the names of all the TV shows to be aired today whose original language is english.

# %%
import requests 
api_key = "e226f4a5f5bace766952aa0d17182959" 
api_link = "https://api.themoviedb.org/3" 
params = { 'api_key':api_key} 
header = {'Accept': 'application/json'} 
response = requests.get(api_link + "/tv/airing_today", headers = header, params=params)
data = response.json()
page = data.get('total_pages')
for i in range(1,page+1):
    params = {'language':'en', 'api_key':api_key,'page':i}
    response = requests.get(api_link + "/tv/airing_today", headers = header, params=params)
    data = response.json()
    result = data.get('results')
    for i in result:
        if i.get('original_language') == 'en':
            print(i.get('name'))
# for i in data['results']:
#     if i['original_language'] == 'en':
#         print(i['name'])
# #         print(i['original_language'])
# Out:
# The Wheel of Time
# Wheel of Fortune
# Maury
# I'm a Celebrity Get Me Out of Here!
# Judge Jerry
# Days of Our Lives
# Bluey
# Legacies
# Rachael Ray
# People Puzzler
# Emmerdale
# PBS NewsHour
# The Daily Show with Trevor Noah
# Richard Osman's House of Games
# Let's Make a Deal
# The Bold and the Beautiful
# Min Badi AlToufan
# Young Sheldon
# Star Trek: Discovery
# Young Justice
# Good Mythical Morning
# Walker
# The Tonight Show Starring Jimmy Fallon
# Moneybags
# General Hospital
# Jeopardy!
# Bull
# The People's Court
# The View
# Tamron Hall
# Gossip Girl
# Dr. Phil
# Sesame Street
# Tug of Words
# Claimed and Shamed
# EastEnders
# Advokado
# Critical Role
# The Ellen DeGeneres Show
# Family Feud Canada
# The Sex Lives of College Girls
# The Late Show with Stephen Colbert
# LIVE with Kelly and Ryan
# Question Time
# Hot Ones
# The Young and the Restless
# Chain Reaction
# Temple
# Project Runway
# Mock the Week
# The Damage Report with John Iadarola
# Tacoma FD
# The First 48
# Judy Justice
# Guilty Party
# Masterchef: The Professionals
# Santa Inc.
# WWE Main Event
# The Challenge: All Stars
# Ghosts
# WWE NXT UK
# Jamie Johnson
# B Positive
# Ragdoll
# Chrisley Knows Best
# gen:LOCK
# Canada's Drag Race
# Pip and Posy
# 24 Hours in A&E
# Rugrats
# The Real Housewives: Ultimate Girls Trip
# Baking It
# Paris in Love
# The Russell Howard Hour
# Paranormal Caught on Camera
# The Great Kiwi Bake Off
# Big Timber
# House Hunters
# United States of Al
# Buried In The Backyard
# Queen of the Universe
# Christmas Cookie Challenge
# House of Salt and Sorrows
# Inside the Tower of London
# Wolfsland
# The Browns
# Cherry Blossom UK Tour Documentary
# The Kids Tonight Show
# Allegory: A Tapestry of Guru Nanak's Travels
# Love, Honor & Betray
# Our Time UCF Knights Football
# F1 Weekend Warm-Up
# Will This Work?: Melon Station (2021)
# Will This Work? (2021)
# Shaq Life
# Beyond Uncharted Territory
# Surgeons: At the Edge of Life
# ល្បែងស្នេហ៍ទេពអប្សរ
# Realtimehistory
# Impact Wrestling
# The Great Christmas Light Fight
# The Rachel Maddow Show
# Attack on Pearl Harbor: Minute by Minute
# Unapologetic
# The Peculiar Pawnbroker
# The Conversation
# The Not-Too-Late Show with Elmo
# The Zoo
# The Game
# The Martin Lewis Money Show
# Floribama Shore
# Double Shot at Love
# ASK THE SIDEMEN
# Winter Walks
# Barnwood Builders
# Advent Calendar

# %% [markdown]
# ### statement:
# Count the number of males and females in the cast of "Money Heist" using the TMDb API. id:71446

# %%
import requests 
api_key = "e226f4a5f5bace766952aa0d17182959" 
api_link = "https://api.themoviedb.org/3" 
params = {'query':'Money Heist','api_key':api_key} 
header = {'Accept': 'application/json'} 
response = requests.get(api_link + "/search/tv", headers = header, params=params)
data = response.json()
ID = data['results'][0]['id']
response = requests.get(api_link + "/tv/"+str(ID)+"/aggregate_credits", headers = header, params=params)
data = response.json()
male = 0
female = 0
for i in data['cast']:
    if i['gender'] == 2:
        female += 1
    else:
        male += 1
print(female,male)
data
# Out:
# 52 68
# {'cast': [{'adult': False,
#    'gender': 2,
#    'id': 1180134,
#    'known_for_department': 'Acting',
#    'name': 'Mario de la Rosa',
#    'original_name': 'Mario de la Rosa',
#    'popularity': 2.233,
#    'profile_path': '/2EafPw8ar2K8eWfIsx8d5HByBgE.jpg',
#    'roles': [{'credit_id': '5ac12fb50e0a260c0100af20',
#      'character': 'Suárez',
#      'episode_count': 49}],
#    'total_episode_count': 49,
#    'order': 115},
#   {'adult': False,
#    'gender': 2,
#    'id': 1340020,
#    'known_for_department': 'Acting',
#    'name': 'Álvaro Morte',
#    'original_name': 'Álvaro Morte',
#    'popularity': 6.894,
#    'profile_path': '/2TGPhdpRC5wjdFEJqnLYiN5kbwg.jpg',
#    'roles': [{'credit_id': '5d3376536a300b1834ac44e5',
#      'character': "Sergio 'El Profesor' Marquina / Salvador 'Salva' Martin",
#      'episode_count': 41}],
#    'total_episode_count': 41,
#    'order': 0},
#   {'adult': False,
#    'gender': 1,
#    'id': 947514,
#    'known_for_department': 'Acting',
#    'name': 'Itziar Ituño',
#    'original_name': 'Itziar Ituño',
#    'popularity': 10.626,
#    'profile_path': '/vnrfL03NwRJ1X82esSNUoYzASGr.jpg',
#    'roles': [{'credit_id': '5a4225d29251411fab04d6ea',
#      'character': "Raquel 'Lisboa' Murillo",
#      'episode_count': 41}],
#    'total_episode_count': 41,
#    'order': 1},
#   {'adult': False,
#    'gender': 1,
#    'id': 1042728,
#    'known_for_department': 'Acting',
#    'name': 'Úrsula Corberó',
#    'original_name': 'Úrsula Corberó',
#    'popularity': 27.751,
#    'profile_path': '/wfy2YBmaGkH5kl60y3P03tTAMMc.jpg',
#    'roles': [{'credit_id': '5a422574c3a36858c5036f41',
#      'character': "Silene 'Tokio' Oliveira",
#      'episode_count': 41}],
#    'total_episode_count': 41,
#    'order': 2},
#   {'adult': False,
#    'gender': 2,
#    'id': 1109836,
#    'known_for_department': 'Acting',
#    'name': 'Pedro Alonso',
#    'original_name': 'Pedro Alonso',
#    'popularity': 3.901,
#    'profile_path': '/38HeVKeOBztVYrLJOWzAtEZiB02.jpg',
#    'roles': [{'credit_id': '5d34b7bd17792c0012bcac8d',
#      'character': "Andrés 'Berlin' de Fonollosa",
#      'episode_count': 41}],
#    'total_episode_count': 41,
#    'order': 4},
#   {'adult': False,
#    'gender': 2,
#    'id': 1972706,
#    'known_for_department': 'Acting',
#    'name': 'Jaime Lorente',
#    'original_name': 'Jaime Lorente',
#    'popularity': 5.805,
#    'profile_path': '/nLaxzU92z14FIbe25sE8jDMIThZ.jpg',
#    'roles': [{'credit_id': '5a773f46c3a3682273001229',
#      'character': "Dani 'Denver' Ramos",
#      'episode_count': 41}],
#    'total_episode_count': 41,
#    'order': 5},
#   {'adult': False,
#    'gender': 2,
#    'id': 1428896,
#    'known_for_department': 'Acting',
#    'name': 'Miguel Herrán',
#    'original_name': 'Miguel Herrán',
#    'popularity': 9.468,
#    'profile_path': '/jJ8UKek4GvQrQUP9q97Kq2MWVqi.jpg',
#    'roles': [{'credit_id': '5a4227c89251411f4f04a5b3',
#      'character': "Aníbal 'Río' Cortés",
#      'episode_count': 41}],
#    'total_episode_count': 41,
#    'order': 6},
#   {'adult': False,
#    'gender': 1,
#    'id': 1972707,
#    'known_for_department': 'Acting',
#    'name': 'Esther Acebo',
#    'original_name': 'Esther Acebo',
#    'popularity': 9.176,
#    'profile_path': '/2v2eOKCjnQfY3jCsowtH8wLxFMC.jpg',
#    'roles': [{'credit_id': '5a773f680e0a26598500132a',
#      'character': "Mónica 'Estocolmo' Gaztambide",
#      'episode_count': 41}],
#    'total_episode_count': 41,
#    'order': 7},
#   {'adult': False,
#    'gender': 2,
#    'id': 944099,
#    'known_for_department': 'Acting',
#    'name': 'Enrique Arce',
#    'original_name': 'Enrique Arce',
#    'popularity': 3.339,
#    'profile_path': '/1lACQepfukuZ0l6FnUpMO03WxcJ.jpg',
#    'roles': [{'credit_id': '5a773eeac3a368227b001336',
#      'character': 'Arturo Román',
#      'episode_count': 41}],
#    'total_episode_count': 41,
#    'order': 9},
#   {'adult': False,
#    'gender': 2,
#    'id': 1898026,
#    'known_for_department': 'Acting',
#    'name': 'Darko Peric',
#    'original_name': 'Darko Peric',
#    'popularity': 3.702,
#    'profile_path': '/9IsIRW3PE105bfwen4IzGPXfmQc.jpg',
#    'roles': [{'credit_id': '5a773f9a92514177690011a6',
#      'character': "Mirko 'Helsinki' Dragic",
#      'episode_count': 41}],
#    'total_episode_count': 41,
#    'order': 10},
#   {'adult': False,
#    'gender': 1,
#    'id': 1154732,
#    'known_for_department': 'Acting',
#    'name': 'Anna Gras',
#    'original_name': 'Anna Gras',
#    'popularity': 1.896,
#    'profile_path': '/s2Qg33f410HKj19IaM4M2T9R1L.jpg',
#    'roles': [{'credit_id': '5ac12f9d0e0a264a5704b840',
#      'character': 'Mercedes Colmenar',
#      'episode_count': 33}],
#    'total_episode_count': 33,
#    'order': 115},
#   {'adult': False,
#    'gender': 2,
#    'id': 2013140,
#    'known_for_department': 'Acting',
#    'name': 'Roberto García Ruiz',
#    'original_name': 'Roberto García Ruiz',
#    'popularity': 4.485,
#    'profile_path': '/zaEYmC7DhMHgbdPovfmYVZD8spJ.jpg',
#    'roles': [{'credit_id': '5ac1307dc3a36844480518ec',
#      'character': 'Oslo',
#      'episode_count': 32}],
#    'total_episode_count': 32,
#    'order': 115},
#   {'adult': False,
#    'gender': 1,
#    'id': 1283843,
#    'known_for_department': 'Acting',
#    'name': 'Alba Flores',
#    'original_name': 'Alba Flores',
#    'popularity': 8.489,
#    'profile_path': '/9ExASXw097MyNuSy6N23fpkqpXq.jpg',
#    'roles': [{'credit_id': '618616fb5545ca00953deb5a',
#      'character': "Ágata 'Nairobi' Jiménez",
#      'episode_count': 31}],
#    'total_episode_count': 31,
#    'order': 3},
#   {'adult': False,
#    'gender': 2,
#    'id': 1473729,
#    'known_for_department': 'Acting',
#    'name': 'Fernando Soto',
#    'original_name': 'Fernando Soto',
#    'popularity': 0.784,
#    'profile_path': '/9tqHD2lgTyEaINR6OBQHnPfGVT9.jpg',
#    'roles': [{'credit_id': '5ac12fac0e0a260c3900c475',
#      'character': 'Ángel Rubio',
#      'episode_count': 29}],
#    'total_episode_count': 29,
#    'order': 112},
#   {'adult': False,
#    'gender': 1,
#    'id': 1838089,
#    'known_for_department': 'Acting',
#    'name': 'Clara Alvarado',
#    'original_name': 'Clara Alvarado',
#    'popularity': 3.269,
#    'profile_path': '/9CiG2Hj1vwHw31YO1CkF2a2L0M5.jpg',
#    'roles': [{'credit_id': '5ac1305bc3a3682d9a00b653',
#      'character': 'Ariadna Cascales',
#      'episode_count': 29}],
#    'total_episode_count': 29,
#    'order': 115},
#   {'adult': False,
#    'gender': 2,
#    'id': 18478,
#    'known_for_department': 'Acting',
#    'name': 'Rodrigo de la Serna',
#    'original_name': 'Rodrigo de la Serna',
#    'popularity': 1.4,
#    'profile_path': '/vMuKUJSnEGOmjjLYzVDKGukiaCr.jpg',
#    'roles': [{'credit_id': '5d2e07af839d93000eefbc63',
#      'character': "Martín 'Palermo' Berrote",
#      'episode_count': 26}],
#    'total_episode_count': 26,
#    'order': 8},
#   {'adult': False,
#    'gender': 2,
#    'id': 1131415,
#    'known_for_department': 'Acting',
#    'name': 'Hovik Keuchkerian',
#    'original_name': 'Hovik Keuchkerian',
#    'popularity': 2.517,
#    'profile_path': '/o5cGKWHlZl4RFROYlT2hD95j0lN.jpg',
#    'roles': [{'credit_id': '5d2e078f6a300b000fa4d50c',
#      'character': 'Bogotá',
#      'episode_count': 26}],
#    'total_episode_count': 26,
#    'order': 11},
#   {'adult': False,
#    'gender': 2,
#    'id': 1076809,
#    'known_for_department': 'Acting',
#    'name': 'Luka Peroš',
#    'original_name': 'Luka Peroš',
#    'popularity': 3.179,
#    'profile_path': '/lfh7959EpR9gAvrjObNGXaUg2qF.jpg',
#    'roles': [{'credit_id': '610d419d323eba005dd9c933',
#      'character': "Jakov 'Marsella'",
#      'episode_count': 26}],
#    'total_episode_count': 26,
#    'order': 12},
#   {'adult': False,
#    'gender': 1,
#    'id': 1423493,
#    'known_for_department': 'Acting',
#    'name': 'Belén Cuesta',
#    'original_name': 'Belén Cuesta',
#    'popularity': 2.616,
#    'profile_path': '/xxaNCeIuLh7nZvuCrwANO3zwI5g.jpg',
#    'roles': [{'credit_id': '610d41ae5a4690005ff40b54',
#      'character': "Julia 'Manila'",
#      'episode_count': 26}],
#    'total_episode_count': 26,
#    'order': 13},
#   {'adult': False,
#    'gender': 2,
#    'id': 51902,
#    'known_for_department': 'Acting',
#    'name': 'Fernando Cayo',
#    'original_name': 'Fernando Cayo',
#    'popularity': 2.346,
#    'profile_path': '/sglfXHNFlzOBBLuRrbDkxghSW4H.jpg',
#    'roles': [{'credit_id': '610d41fa323eba005dd9c9d8',
#      'character': 'Luis Tamayo',
#      'episode_count': 26}],
#    'total_episode_count': 26,
#    'order': 14},
#   {'adult': False,
#    'gender': 1,
#    'id': 16442,
#    'known_for_department': 'Acting',
#    'name': 'Najwa Nimri',
#    'original_name': 'Najwa Nimri',
#    'popularity': 6.255,
#    'profile_path': '/hvLbKkDIT4FqSS8djmW5voNd0O4.jpg',
#    'roles': [{'credit_id': '5d2e09e8caab6d1e81a3b6f2',
#      'character': 'Alicia Sierra',
#      'episode_count': 26}],
#    'total_episode_count': 26,
#    'order': 15},
#   {'adult': False,
#    'gender': 2,
#    'id': 1983424,
#    'known_for_department': 'Acting',
#    'name': 'Fran Morcillo',
#    'original_name': 'Fran Morcillo',
#    'popularity': 1.356,
#    'profile_path': '/ovPzGuRvMQhB4OrC6lfxlEGLewD.jpg',
#    'roles': [{'credit_id': '5ac12fcec3a368443f04b026',
#      'character': 'Pablo Ruiz',
#      'episode_count': 22}],
#    'total_episode_count': 22,
#    'order': 114},
#   {'adult': False,
#    'gender': 2,
#    'id': 1027740,
#    'known_for_department': 'Acting',
#    'name': 'Paco Tous',
#    'original_name': 'Paco Tous',
#    'popularity': 4.178,
#    'profile_path': '/fl3tEdiIod0NpMMJv9uL7bQTokd.jpg',
#    'roles': [{'credit_id': '5d31e207caab6d31b2a3da32',
#      'character': "Agustín 'Moscú' Ramos",
#      'episode_count': 21}],
#    'total_episode_count': 21,
#    'order': 111},
#   {'adult': False,
#    'gender': 2,
#    'id': 229766,
#    'known_for_department': 'Acting',
#    'name': 'Miquel García Borda',
#    'original_name': 'Miquel García Borda',
#    'popularity': 1.627,
#    'profile_path': '/cAw6py4F8VjJ0QScGxCTkw6CE99.jpg',
#    'roles': [{'credit_id': '5ac130fd0e0a260c0100b120',
#      'character': 'Alberto Vicuña',
#      'episode_count': 21}],
#    'total_episode_count': 21,
#    'order': 115},
#   {'adult': False,
#    'gender': 2,
#    'id': 1284938,
#    'known_for_department': 'Acting',
#    'name': 'Juan Fernández',
#    'original_name': 'Juan Fernández',
#    'popularity': 1.096,
#    'profile_path': '/biMQMuVw79qKcWLXHebZmAO9lvj.jpg',
#    'roles': [{'credit_id': '5ac12f9292514126b000b337',
#      'character': 'Alfonso Prieto',
#      'episode_count': 20}],
#    'total_episode_count': 20,
#    'order': 88},
#   {'adult': False,
#    'gender': 1,
#    'id': 16975,
#    'known_for_department': 'Acting',
#    'name': 'Kiti Mánver',
#    'original_name': 'Kiti Mánver',
#    'popularity': 1.769,
#    'profile_path': '/1hMLpxmw3HP6yx6LtH0UgMiFGmA.jpg',
#    'roles': [{'credit_id': '5d31dc976a300b5922ad44a7',
#      'character': 'Mariví Fuentes',
#      'episode_count': 18}],
#    'total_episode_count': 18,
#    'order': 12},
#   {'adult': False,
#    'gender': 1,
#    'id': 1976283,
#    'known_for_department': 'Acting',
#    'name': 'Olalla Hernández',
#    'original_name': 'Olalla Hernández',
#    'popularity': 3.192,
#    'profile_path': '/a5PtbDRsMgRBpBxr29Q8obwUnZz.jpg',
#    'roles': [{'credit_id': '5d31def42f8d090010d7edef',
#      'character': 'Amanda',
#      'episode_count': 18}],
#    'total_episode_count': 18,
#    'order': 113},
#   {'adult': False,
#    'gender': 2,
#    'id': 2365759,
#    'known_for_department': 'Acting',
#    'name': 'Carlos Suárez',
#    'original_name': 'Carlos Suárez',
#    'popularity': 0.995,
#    'profile_path': '/u5rNLvm41egbGSyRVisFxkzhyPx.jpg',
#    'roles': [{'credit_id': '5d31de5a1d78f20010e0d64c',
#      'character': 'Miguel Fernández',
#      'episode_count': 18}],
#    'total_episode_count': 18,
#    'order': 114},
#   {'adult': False,
#    'gender': 2,
#    'id': 2365627,
#    'known_for_department': 'Acting',
#    'name': 'Antonio Romero',
#    'original_name': 'Antonio Romero',
#    'popularity': 1.241,
#    'profile_path': '/55YbLYvIjAvkwX7bdT0dHf6wqN0.jpg',
#    'roles': [{'credit_id': '5d31df05caab6d0b29a33da0',
#      'character': 'Benito Antoñanzas',
#      'episode_count': 17}],
#    'total_episode_count': 17,
#    'order': 112},
#   {'adult': False,
#    'gender': 2,
#    'id': 2365626,
#    'known_for_department': 'Acting',
#    'name': 'Ahikar Azcona',
#    'original_name': 'Ahikar Azcona',
#    'popularity': 3.023,
#    'profile_path': '/pQkKg22fvuhx3rrTc9N6C2eXCvG.jpg',
#    'roles': [{'credit_id': '5d31defa2f8d090010d7edfa',
#      'character': 'Matías Caño',
#      'episode_count': 16}],
#    'total_episode_count': 16,
#    'order': 112},
#   {'adult': False,
#    'gender': 2,
#    'id': 16950,
#    'known_for_department': 'Acting',
#    'name': 'Pep Munné',
#    'original_name': 'Pep Munné',
#    'popularity': 0.74,
#    'profile_path': '/t6MJozPb86TkMeUmacWCyborQkW.jpg',
#    'roles': [{'credit_id': '5d31ded56a300b11afa2dfe2',
#      'character': 'Mario Urbaneja',
#      'episode_count': 16}],
#    'total_episode_count': 16,
#    'order': 112},
#   {'adult': False,
#    'gender': 1,
#    'id': 1757167,
#    'known_for_department': 'Acting',
#    'name': 'María Pedraza',
#    'original_name': 'María Pedraza',
#    'popularity': 8.28,
#    'profile_path': '/6Jvw8ftzP2O5nsn0wmERDtpcr8E.jpg',
#    'roles': [{'credit_id': '5a773f8b0e0a265985001351',
#      'character': 'Alison Parker',
#      'episode_count': 15}],
#    'total_episode_count': 15,
#    'order': 10},
#   {'adult': False,
#    'gender': 1,
#    'id': 1289331,
#    'known_for_department': 'Acting',
#    'name': 'Mari Carmen Sánchez',
#    'original_name': 'Mari Carmen Sánchez',
#    'popularity': 1.4,
#    'profile_path': '/ySRvcYRl6K9UdGpXvAmL2uaORG1.jpg',
#    'roles': [{'credit_id': '5d31de4ecaab6d31b2a3cf3a',
#      'character': 'Paquita',
#      'episode_count': 15}],
#    'total_episode_count': 15,
#    'order': 112},
#   {'adult': False,
#    'gender': 1,
#    'id': 2013144,
#    'known_for_department': 'Acting',
#    'name': 'Cristina Saavedra',
#    'original_name': 'Cristina Saavedra',
#    'popularity': 2.271,
#    'profile_path': '/jtMSb1wRDxTsxiqcB0PVXzTKWUi.jpg',
#    'roles': [{'credit_id': '5ac131080e0a260c1400bf66',
#      'character': 'Ella misma',
#      'episode_count': 11}],
#    'total_episode_count': 11,
#    'order': 96},
#   {'adult': False,
#    'gender': 2,
#    'id': 1489778,
#    'known_for_department': 'Acting',
#    'name': 'Mikel Bustamante',
#    'original_name': 'Mikel Bustamante',
#    'popularity': 0.6,
#    'profile_path': '/aTzyqha9XMs2ggMvu2c579OtJ96.jpg',
#    'roles': [{'credit_id': '5d31dfa81d78f2000fe0d7bd',
#      'character': 'Martínez',
#      'episode_count': 10}],
#    'total_episode_count': 10,
#    'order': 112},
#   {'adult': False,
#    'gender': 1,
#    'id': 2013159,
#    'known_for_department': 'Acting',
#    'name': 'Agnès Llobet',
#    'original_name': 'Agnès Llobet',
#    'popularity': 1.96,
#    'profile_path': '/3xAzKeKVbYLYJ6lvMoRRxy2yEMq.jpg',
#    'roles': [{'credit_id': '5ac133dc9251416018049b5e',
#      'character': 'Pilar',
#      'episode_count': 10}],
#    'total_episode_count': 10,
#    'order': 115},
#   {'adult': False,
#    'gender': 0,
#    'id': 2013174,
#    'known_for_department': 'Acting',
#    'name': 'Lobo',
#    'original_name': 'Lobo',
#    'popularity': 0.6,
#    'profile_path': None,
#    'roles': [{'credit_id': '5ac136b7925141272000c804',
#      'character': 'Darko Dragic',
#      'episode_count': 10}],
#    'total_episode_count': 10,
#    'order': 115},
#   {'adult': False,
#    'gender': 1,
#    'id': 1487969,
#    'known_for_department': 'Acting',
#    'name': 'Naia Guz Sanchez',
#    'original_name': 'Naia Guz Sanchez',
#    'popularity': 4.383,
#    'profile_path': '/7TX9lvcFbfHLi9pV7jRo7qLSBSH.jpg',
#    'roles': [{'credit_id': '5ac130640e0a264a4e04eff6',
#      'character': 'Paula Vicuña',
#      'episode_count': 8}],
#    'total_episode_count': 8,
#    'order': 81},
#   {'adult': False,
#    'gender': 1,
#    'id': 131085,
#    'known_for_department': 'Acting',
#    'name': 'Diana Gómez',
#    'original_name': 'Diana Gómez',
#    'popularity': 3.65,
#    'profile_path': '/sB06F3ke3Y0R2JXUx94w8khsVku.jpg',
#    'roles': [{'credit_id': '5d31d9532f8d090012d7eaf4',
#      'character': 'Tatiana',
#      'episode_count': 8}],
#    'total_episode_count': 8,
#    'order': 112},
#   {'adult': False,
#    'gender': 2,
#    'id': 122461,
#    'known_for_department': 'Acting',
#    'name': 'Ramon Agirre',
#    'original_name': 'Ramon Agirre',
#    'popularity': 0.862,
#    'profile_path': '/iDLBCTz6mANvckYPL3KDkUTLfl6.jpg',
#    'roles': [{'credit_id': '610d56a85bce9e002cfa4104',
#      'character': 'Benjamín',
#      'episode_count': 7}],
#    'total_episode_count': 7,
#    'order': 112},
#   {'adult': False,
#    'gender': 2,
#    'id': 1320171,
#    'known_for_department': 'Acting',
#    'name': 'Pedro Pablo Isla',
#    'original_name': 'Pedro Pablo Isla',
#    'popularity': 0.608,
#    'profile_path': '/qFwWd4OCvPd1OIvUCx4JhopNRMd.jpg',
#    'roles': [{'credit_id': '5ac133e5c3a3684448051e9f',
#      'character': 'Jacinto',
#      'episode_count': 7}],
#    'total_episode_count': 7,
#    'order': 114},
#   {'adult': False,
#    'gender': 0,
#    'id': 2013162,
#    'known_for_department': 'Acting',
#    'name': 'Xabi Ortuzar',
#    'original_name': 'Xabi Ortuzar',
#    'popularity': 1.111,
#    'profile_path': '/y4qLbenSC3bmCU9seyJ8IGZmeD.jpg',
#    'roles': [{'credit_id': '5ac1352b92514126b000bae4',
#      'character': 'Gómez',
#      'episode_count': 6}],
#    'total_episode_count': 6,
#    'order': 30},
#   {'adult': False,
#    'gender': 1,
#    'id': 1148666,
#    'known_for_department': 'Acting',
#    'name': 'Bárbara de Lema',
#    'original_name': 'Bárbara de Lema',
#    'popularity': 0.6,
#    'profile_path': '/p8TbweB5glrrOHFz05hO9ZTA1xM.jpg',
#    'roles': [{'credit_id': '61385ee4da9ef20090c53061',
#      'character': 'Periodista',
#      'episode_count': 5}],
#    'total_episode_count': 5,
#    'order': 106},
#   {'adult': False,
#    'gender': 1,
#    'id': 1762552,
#    'known_for_department': 'Acting',
#    'name': 'Mery Cabezuelo',
#    'original_name': 'Mery Cabezuelo',
#    'popularity': 0.98,
#    'profile_path': '/3ZGaO72qJOn00U9iBxIVYNqLMhl.jpg',
#    'roles': [{'credit_id': '61385db3091e62002cecfd56',
#      'character': 'Periodista',
#      'episode_count': 5}],
#    'total_episode_count': 5,
#    'order': 107},
#   {'adult': False,
#    'gender': 0,
#    'id': 1331588,
#    'known_for_department': 'Acting',
#    'name': 'José Manuel Seda',
#    'original_name': 'José Manuel Seda',
#    'popularity': 1.641,
#    'profile_path': '/sTkfJeYfoJ8aZzjDXBl969KTGqu.jpg',
#    'roles': [{'credit_id': '6138e5eb2cde98002b6e259b',
#      'character': 'Sagasta',
#      'episode_count': 5}],
#    'total_episode_count': 5,
#    'order': 114},
#   {'adult': False,
#    'gender': 0,
#    'id': 2013149,
#    'known_for_department': 'Acting',
#    'name': 'Peter Nikolas',
#    'original_name': 'Peter Nikolas',
#    'popularity': 0.996,
#    'profile_path': '/4b8ugGK6TsVvGGjTCqA7MchBYoh.jpg',
#    'roles': [{'credit_id': '5ac1326392514126c300b598',
#      'character': 'Nikolai Dimitrievich',
#      'episode_count': 5}],
#    'total_episode_count': 5,
#    'order': 114},
#   {'adult': False,
#    'gender': 1,
#    'id': 16976,
#    'known_for_department': 'Acting',
#    'name': 'Elisabet Gelabert',
#    'original_name': 'Elisabet Gelabert',
#    'popularity': 1.789,
#    'profile_path': '/7X2UmMz1CrdB7CqpruLItxWa1av.jpg',
#    'roles': [{'credit_id': '5ac133ec0e0a260c4d00c4e1',
#      'character': 'Mari Carmen',
#      'episode_count': 5}],
#    'total_episode_count': 5,
#    'order': 114},
#   {'adult': False,
#    'gender': 2,
#    'id': 935934,
#    'known_for_department': 'Acting',
#    'name': 'Pep Tosar',
#    'original_name': 'Pep Tosar',
#    'popularity': 1.475,
#    'profile_path': '/smKTVFGwQxxB7xViCg7pp3TST9R.jpg',
#    'roles': [{'credit_id': '5ac12ff7c3a3682d9a00b5c2',
#      'character': 'Sánchez',
#      'episode_count': 5}],
#    'total_episode_count': 5,
#    'order': 115},
#   {'adult': False,
#    'gender': 2,
#    'id': 2013163,
#    'known_for_department': 'Acting',
#    'name': 'Praxedes Nieto',
#    'original_name': 'Praxedes Nieto',
#    'popularity': 0.6,
#    'profile_path': '/3gixDSNIZsD3S3hbo17cyeqrqQZ.jpg',
#    'roles': [{'credit_id': '5ac1353dc3a3682d3500c57b',
#      'character': 'Detenido',
#      'episode_count': 5}],
#    'total_episode_count': 5,
#    'order': 115},
#   {'adult': False,
#    'gender': 1,
#    'id': 2013194,
#    'known_for_department': 'Acting',
#    'name': 'Sara Solomando',
#    'original_name': 'Sara Solomando',
#    'popularity': 0.98,
#    'profile_path': None,
#    'roles': [{'credit_id': '5d31dfaf1d78f20011e0d8f8',
#      'character': 'Periodista',
#      'episode_count': 4}],
#    'total_episode_count': 4,
#    'order': 93},
#   {'adult': False,
#    'gender': 2,
#    'id': 33412,
#    'known_for_department': 'Acting',
#    'name': 'Alberto Amarilla',
#    'original_name': 'Alberto Amarilla',
#    'popularity': 1.471,
#    'profile_path': '/gv3K3xFqKdd82KyBk4FZzKESHRM.jpg',
#    'roles': [{'credit_id': '6138e9e71b7294008f632a29',
#      'character': 'Ramiro',
#      'episode_count': 4}],
#    'total_episode_count': 4,
#    'order': 112},
#   {'adult': False,
#    'gender': 0,
#    'id': 1849779,
#    'known_for_department': 'Acting',
#    'name': 'Javier Perdiguero',
#    'original_name': 'Javier Perdiguero',
#    'popularity': 1.008,
#    'profile_path': '/9tDPho39gwEPXpmvVtXpeNtxy93.jpg',
#    'roles': [{'credit_id': '5ac13535c3a3682db500c4da',
#      'character': 'Agente Romero',
#      'episode_count': 4}],
#    'total_episode_count': 4,
#    'order': 115},
#   {'adult': False,
#    'gender': 1,
#    'id': 2013166,
#    'known_for_department': 'Acting',
#    'name': 'Erika Bleda',
#    'original_name': 'Erika Bleda',
#    'popularity': 2.81,
#    'profile_path': '/38XBJJe1v3JfuIlHe05E2fa8iwd.jpg',
#    'roles': [{'credit_id': '5ac1360892514126be00cd71',
#      'character': 'Presentadora',
#      'episode_count': 4}],
#    'total_episode_count': 4,
#    'order': 115},
#   {'adult': False,
#    'gender': 2,
#    'id': 2365615,
#    'known_for_department': 'Acting',
#    'name': 'Luca Antón',
#    'original_name': 'Luca Antón',
#    'popularity': 0.6,
#    'profile_path': None,
#    'roles': [{'credit_id': '5d31d940caab6d31b2a3bbae',
#      'character': 'Cincinnati Ramos',
#      'episode_count': 3}],
#    'total_episode_count': 3,
#    'order': 68},
#   {'adult': False,
#    'gender': 2,
#    'id': 2366232,
#    'known_for_department': 'Acting',
#    'name': 'Rafael Rojas',
#    'original_name': 'Rafael Rojas',
#    'popularity': 0.6,
#    'profile_path': '/dSD8aihOuopcCunj176Pl9Iq16B.jpg',
#    'roles': [{'credit_id': '5d32f7246a300b5922b07d9c',
#      'character': 'Jefe de Estado Mayor de la Defensa',
#      'episode_count': 3}],
#    'total_episode_count': 3,
#    'order': 79},
#   {'adult': False,
#    'gender': 2,
#    'id': 2365647,
#    'known_for_department': 'Acting',
#    'name': 'Paolo Sanminiatelli',
#    'original_name': 'Paolo Sanminiatelli',
#    'popularity': 0.6,
#    'profile_path': '/6GbPC3FEM9XyzUzZIrBNqXRT07Y.jpg',
#    'roles': [{'credit_id': '5d31e3f91d78f2000fe0e058',
#      'character': 'Giovanni',
#      'episode_count': 3}],
#    'total_episode_count': 3,
#    'order': 80},
#   {'adult': False,
#    'gender': 0,
#    'id': 2543569,
#    'known_for_department': 'Acting',
#    'name': 'Rocco Narva',
#    'original_name': 'Rocco Narva',
#    'popularity': 0.6,
#    'profile_path': None,
#    'roles': [{'credit_id': '610d545d38469a005cae2fe3',
#      'character': 'Suárez',
#      'episode_count': 3}],
#    'total_episode_count': 3,
#    'order': 90},
#   {'adult': False,
#    'gender': 0,
#    'id': 1349338,
#    'known_for_department': 'Acting',
#    'name': 'Mustafa Haidari',
#    'original_name': 'Mustafa Haidari',
#    'popularity': 0.648,
#    'profile_path': '/ya9C139lPT5rOBLWSi1PVa9Ian3.jpg',
#    'roles': [{'credit_id': '610d5612f6fd18002dfebd1e',
#      'character': 'Shakir (voice)',
#      'episode_count': 3}],
#    'total_episode_count': 3,
#    'order': 94},
#   {'adult': False,
#    'gender': 0,
#    'id': 2182008,
#    'known_for_department': 'Acting',
#    'name': 'Roman Rymar',
#    'original_name': 'Roman Rymar',
#    'popularity': 0.6,
#    'profile_path': None,
#    'roles': [{'credit_id': '610d57a04cbe12002c5f287f',
#      'character': 'El Polaco',
#      'episode_count': 2},
#     {'credit_id': '6138e63207a808008bdf982d',
#      'character': 'Boris',
#      'episode_count': 1}],
#    'total_episode_count': 3,
#    'order': 101},
#   {'adult': False,
#    'gender': 1,
#    'id': 1331728,
#    'known_for_department': 'Acting',
#    'name': 'Adelfa Calvo',
#    'original_name': 'Adelfa Calvo',
#    'popularity': 0.732,
#    'profile_path': '/uC6ZquT9cTTgZfJ1SLMTYZXrU1u.jpg',
#    'roles': [{'credit_id': '5ac12fbfc3a3684448051786',
#      'character': 'Madre de Tokio',
#      'episode_count': 3}],
#    'total_episode_count': 3,
#    'order': 104},
#   {'adult': False,
#    'gender': 0,
#    'id': 1923586,
#    'known_for_department': 'Acting',
#    'name': 'Néstor Arnas',
#    'original_name': 'Néstor Arnas',
#    'popularity': 1.01,
#    'profile_path': '/q8MquZMavGYRzOC24j7lf3DV62S.jpg',
#    'roles': [{'credit_id': '5ac131f40e0a264a4e04f2e6',
#      'character': 'Médico',
#      'episode_count': 3}],
#    'total_episode_count': 3,
#    'order': 108},
#   {'adult': False,
#    'gender': 2,
#    'id': 578014,
#    'known_for_department': 'Acting',
#    'name': 'Patrick Criado',
#    'original_name': 'Patrick Criado',
#    'popularity': 1.092,
#    'profile_path': '/hq0hxTaaiOSRBXsQm0UEKh5NLKG.jpg',
#    'roles': [{'credit_id': '6138e609d036b6002719c042',
#      'character': 'Rafael de Fonollosa',
#      'episode_count': 3}],
#    'total_episode_count': 3,
#    'order': 111},
#   {'adult': False,
#    'gender': 2,
#    'id': 2151412,
#    'known_for_department': 'Acting',
#    'name': 'Antonio García Ferreras',
#    'original_name': 'Antonio García Ferreras',
#    'popularity': 0.6,
#    'profile_path': '/vrH0mAxj7MSZxOpRDYDTuA4H5t6.jpg',
#    'roles': [{'credit_id': '5e898f56b84f940014cb653e',
#      'character': 'Él mismo',
#      'episode_count': 3}],
#    'total_episode_count': 3,
#    'order': 111},
#   {'adult': False,
#    'gender': 1,
#    'id': 2013150,
#    'known_for_department': 'Acting',
#    'name': 'Oti Manzano',
#    'original_name': 'Oti Manzano',
#    'popularity': 0.726,
#    'profile_path': '/u7CL3lYaXZAjDWkfe8XOkMQ513v.jpg',
#    'roles': [{'credit_id': '5ac132770e0a264a5704bd4b',
#      'character': 'Madre de Río',
#      'episode_count': 3}],
#    'total_episode_count': 3,
#    'order': 114},
#   {'adult': False,
#    'gender': 2,
#    'id': 1491227,
#    'known_for_department': 'Acting',
#    'name': 'Óscar Zafra',
#    'original_name': 'Óscar Zafra',
#    'popularity': 1.073,
#    'profile_path': '/latkUliJh9WcQXucVzChFlw6Z11.jpg',
#    'roles': [{'credit_id': '5ac1326dc3a3682d9a00b999',
#      'character': 'Paco Cortés',
#      'episode_count': 3}],
#    'total_episode_count': 3,
#    'order': 114},
#   {'adult': False,
#    'gender': 0,
#    'id': 2013170,
#    'known_for_department': 'Acting',
#    'name': 'Mario Mayo',
#    'original_name': 'Mario Mayo',
#    'popularity': 1.22,
#    'profile_path': '/xzEjSgLCkrwQ1HZ7OY6CbSNM9wM.jpg',
#    'roles': [{'credit_id': '5ac136909251416018049efd',
#      'character': 'Policía',
#      'episode_count': 3}],
#    'total_episode_count': 3,
#    'order': 115},
#   {'adult': False,
#    'gender': 0,
#    'id': 2013186,
#    'known_for_department': 'Acting',
#    'name': 'Gloria García Barquero',
#    'original_name': 'Gloria García Barquero',
#    'popularity': 0.6,
#    'profile_path': '/3GyuLBCp1CL1HgYyephYGObpkfA.jpg',
#    'roles': [{'credit_id': '5ac137a90e0a260c4d00ca9d',
#      'character': 'Teniente Lorenzo',
#      'episode_count': 3}],
#    'total_episode_count': 3,
#    'order': 115},
#   {'adult': False,
#    'gender': 0,
#    'id': 2013168,
#    'known_for_department': 'Acting',
#    'name': 'Fran Morales',
#    'original_name': 'Fran Morales',
#    'popularity': 0.6,
#    'profile_path': '/pZDK8aoKWVaGffiNNr27vc2GFFt.jpg',
#    'roles': [{'credit_id': '5ac1367e925141271200c6b8',
#      'character': 'Policía',
#      'episode_count': 3}],
#    'total_episode_count': 3,
#    'order': 115},
#   {'adult': False,
#    'gender': 0,
#    'id': 1301926,
#    'known_for_department': 'Acting',
#    'name': 'Pere Brasó',
#    'original_name': 'Pere Brasó',
#    'popularity': 0.6,
#    'profile_path': '/ajCYIfizzSwi95NPztJtSgJr4qF.jpg',
#    'roles': [{'credit_id': '5ac136890e0a260c4d00c8eb',
#      'character': 'Agente Pérez',
#      'episode_count': 3}],
#    'total_episode_count': 3,
#    'order': 115},
#   {'adult': False,
#    'gender': 2,
#    'id': 102226,
#    'known_for_department': 'Acting',
#    'name': 'Chema Ruiz',
#    'original_name': 'Chema Ruiz',
#    'popularity': 0.994,
#    'profile_path': '/zStHsJjfm4J00CRsqyP2brMIJKW.jpg',
#    'roles': [{'credit_id': '5d31e0966a300b1834a7d24d',
#      'character': 'Ministro de Interior',
#      'episode_count': 2}],
#    'total_episode_count': 2,
#    'order': 68},
#   {'adult': False,
#    'gender': 1,
#    'id': 2365614,
#    'known_for_department': 'Acting',
#    'name': 'Dariam Coco',
#    'original_name': 'Dariam Coco',
#    'popularity': 0.6,
#    'profile_path': '/jhobanaZRtzdMUeNvm5CtApm8tI.jpg',
#    'roles': [{'credit_id': '5d31d92bcaab6d1640a547f6',
#      'character': 'Amiga de Tokio',
#      'episode_count': 2}],
#    'total_episode_count': 2,
#    'order': 73},
#   {'adult': False,
#    'gender': 1,
#    'id': 1915026,
#    'known_for_department': 'Acting',
#    'name': 'Chacha Huang',
#    'original_name': 'Chacha Huang',
#    'popularity': 2.178,
#    'profile_path': '/dlUyxxcts0ovopsZVMWXRrIpV1M.jpg',
#    'roles': [{'credit_id': '5d31d9316a300b11afa2cf8a',
#      'character': 'Amiga de Tokio',
#      'episode_count': 2}],
#    'total_episode_count': 2,
#    'order': 73},
#   {'adult': False,
#    'gender': 2,
#    'id': 1328983,
#    'known_for_department': 'Acting',
#    'name': 'Neymar Jr',
#    'original_name': 'Neymar Jr',
#    'popularity': 1.413,
#    'profile_path': '/8887Hq0XyckSVy7xfHIUikt7qRO.jpg',
#    'roles': [{'credit_id': '5d668705ba4802610c26823c',
#      'character': 'João',
#      'episode_count': 2}],
#    'total_episode_count': 2,
#    'order': 80},
#   {'adult': False,
#    'gender': 2,
#    'id': 1485149,
#    'known_for_department': 'Acting',
#    'name': 'Jesús Lloveras',
#    'original_name': 'Jesús Lloveras',
#    'popularity': 0.729,
#    'profile_path': '/c4qASKR8pxBxSYwLWd937VzkdRw.jpg',
#    'roles': [{'credit_id': '5d31d9381d78f2000fe0c286',
#      'character': 'Adiestrador de Tokio',
#      'episode_count': 2}],
#    'total_episode_count': 2,
#    'order': 82},
#   {'adult': False,
#    'gender': 2,
#    'id': 1568099,
#    'known_for_department': 'Acting',
#    'name': 'Javier Bolea',
#    'original_name': 'Javier Bolea',
#    'popularity': 0.6,
#    'profile_path': '/iNX4u07SukORiF0osqYg1gzU2Kx.jpg',
#    'roles': [{'credit_id': '5d31dfc62f8d090010d7f1a3',
#      'character': 'Periodista',
#      'episode_count': 2}],
#    'total_episode_count': 2,
#    'order': 87},
#   {'adult': False,
#    'gender': 0,
#    'id': 570521,
#    'known_for_department': 'Acting',
#    'name': 'Manuel Gancedo',
#    'original_name': 'Manuel Gancedo',
#    'popularity': 1.008,
#    'profile_path': None,
#    'roles': [{'credit_id': '610d4e03f6fd180047c9eee6',
#      'character': 'Cliente bar',
#      'episode_count': 2}],
#    'total_episode_count': 2,
#    'order': 88},
#   {'adult': False,
#    'gender': 1,
#    'id': 1355556,
#    'known_for_department': 'Acting',
#    'name': 'Irene Molina',
#    'original_name': 'Irene Molina',
#    'popularity': 0.6,
#    'profile_path': '/redTPq0T0Rz0cH0JqYaLzez4exl.jpg',
#    'roles': [{'credit_id': '5d31dfbe6a300b5922ad50d0',
#      'character': 'Periodista',
#      'episode_count': 2}],
#    'total_episode_count': 2,
#    'order': 89},
#   {'adult': False,
#    'gender': 1,
#    'id': 2365628,
#    'known_for_department': 'Acting',
#    'name': 'Déborah Guerrero',
#    'original_name': 'Déborah Guerrero',
#    'popularity': 0.6,
#    'profile_path': '/mdhm8bZbCkXzcfPca3eG5egeaCl.jpg',
#    'roles': [{'credit_id': '5d31dfcccaab6d1dfc992e06',
#      'character': 'Periodista',
#      'episode_count': 2}],
#    'total_episode_count': 2,
#    'order': 89},
#   {'adult': False,
#    'gender': 0,
#    'id': 2014130,
#    'known_for_department': 'Acting',
#    'name': 'Edward J. Bentley',
#    'original_name': 'Edward J. Bentley',
#    'popularity': 0.6,
#    'profile_path': None,
#    'roles': [{'credit_id': '610d56af38469a005cae3622',
#      'character': '',
#      'episode_count': 2}],
#    'total_episode_count': 2,
#    'order': 94},
#   {'adult': False,
#    'gender': 0,
#    'id': 1537400,
#    'known_for_department': 'Acting',
#    'name': 'Maya Murofushi',
#    'original_name': 'Maya Murofushi',
#    'popularity': 0.6,
#    'profile_path': None,
#    'roles': [{'credit_id': '610d57735a4690002526585c',
#      'character': 'Periodista',
#      'episode_count': 2}],
#    'total_episode_count': 2,
#    'order': 94},
#   {'adult': False,
#    'gender': 0,
#    'id': 2928108,
#    'known_for_department': 'Acting',
#    'name': 'Marjorie Glantz',
#    'original_name': 'Marjorie Glantz',
#    'popularity': 0.6,
#    'profile_path': '/oaCwz4loyMRnSzZy8bHhaGz158K.jpg',
#    'roles': [{'credit_id': '610d57068138310045ab63d1',
#      'character': 'Periodista',
#      'episode_count': 2}],
#    'total_episode_count': 2,
#    'order': 94},
#   {'adult': False,
#    'gender': 0,
#    'id': 1752485,
#    'known_for_department': 'Acting',
#    'name': 'Marina Esteve',
#    'original_name': 'Marina Esteve',
#    'popularity': 0.6,
#    'profile_path': '/x8zYBUp1RlexPj6oAN5t2OYW0iA.jpg',
#    'roles': [{'credit_id': '610d56d5813831002d88f532',
#      'character': 'Periodista',
#      'episode_count': 2}],
#    'total_episode_count': 2,
#    'order': 94},
#   {'adult': False,
#    'gender': 0,
#    'id': 1497591,
#    'known_for_department': 'Acting',
#    'name': 'Ajay Jethi',
#    'original_name': 'Ajay Jethi',
#    'popularity': 0.6,
#    'profile_path': None,
#    'roles': [{'credit_id': '610d56915bce9e002cfa40a3',
#      'character': 'Shakir',
#      'episode_count': 2}],
#    'total_episode_count': 2,
#    'order': 94},
#   {'adult': False,
#    'gender': 0,
#    'id': 3188600,
#    'known_for_department': 'Acting',
#    'name': 'Francisco Javier Pastor',
#    'original_name': 'Francisco Javier Pastor',
#    'popularity': 0.6,
#    'profile_path': None,
#    'roles': [{'credit_id': '610d5789323eba002fbec47a',
#      'character': 'Dragan',
#      'episode_count': 2}],
#    'total_episode_count': 2,
#    'order': 95},
#   {'adult': False,
#    'gender': 2,
#    'id': 2270206,
#    'known_for_department': 'Acting',
#    'name': 'Xavi Sáez',
#    'original_name': 'Xavi Sáez',
#    'popularity': 0.836,
#    'profile_path': None,
#    'roles': [{'credit_id': '610d57d5f6fd18002dfec1ad',
#      'character': 'Policía',
#      'episode_count': 2}],
#    'total_episode_count': 2,
#    'order': 96},
#   {'adult': False,
#    'gender': 0,
#    'id': 3188603,
#    'known_for_department': 'Acting',
#    'name': 'Florencia Nocetti',
#    'original_name': 'Florencia Nocetti',
#    'popularity': 0.6,
#    'profile_path': None,
#    'roles': [{'credit_id': '610d587eb339030046fde11a',
#      'character': 'Rosario Barremechea',
#      'episode_count': 2}],
#    'total_episode_count': 2,
#    'order': 108},
#   {'adult': False,
#    'gender': 2,
#    'id': 121689,
#    'known_for_department': 'Acting',
#    'name': 'Miguel Ángel Silvestre',
#    'original_name': 'Miguel Ángel Silvestre',
#    'popularity': 1.927,
#    'profile_path': '/9RI6vIKvfXJTVyKjVoWE86icZqd.jpg',
#    'roles': [{'credit_id': '6138e61fcede690060fef115',
#      'character': 'René',
#      'episode_count': 2}],
#    'total_episode_count': 2,
#    'order': 114},
#   {'adult': False,
#    'gender': 1,
#    'id': 2013158,
#    'known_for_department': 'Acting',
#    'name': 'Montse Peidró',
#    'original_name': 'Montse Peidró',
#    'popularity': 0.6,
#    'profile_path': '/9qQdZzuMZLVDVKS4HttTYIhC7YC.jpg',
#    'roles': [{'credit_id': '5ac133d6c3a3682d3300b65c',
#      'character': 'Farmacéutica',
#      'episode_count': 2}],
#    'total_episode_count': 2,
#    'order': 114},
#   {'adult': False,
#    'gender': 2,
#    'id': 233950,
#    'known_for_department': 'Directing',
#    'name': 'Alejandro Bazzano',
#    'original_name': 'Alejandro Bazzano',
#    'popularity': 0.985,
#    'profile_path': '/dOETAQu48p5CfZnYwtabe8Wbk0b.jpg',
#    'roles': [{'credit_id': '5ac1373ec3a3682d9a00c0c3',
#      'character': 'Médico ucraniano',
#      'episode_count': 2}],
#    'total_episode_count': 2,
#    'order': 115},
#   {'adult': False,
#    'gender': 1,
#    'id': 2013164,
#    'known_for_department': 'Acting',
#    'name': 'Leticia Etala',
#    'original_name': 'Leticia Etala',
#    'popularity': 1.273,
#    'profile_path': '/wObNso37fj0dZ6JEnBs6pCXuDiw.jpg',
#    'roles': [{'credit_id': '5ac135950e0a260c4a00d676',
#      'character': 'Agente de policía',
#      'episode_count': 2}],
#    'total_episode_count': 2,
#    'order': 115},
#   {'adult': False,
#    'gender': 1,
#    'id': 2007383,
#    'known_for_department': 'Acting',
#    'name': 'Cristina Pardo',
#    'original_name': 'Cristina Pardo',
#    'popularity': 0.6,
#    'profile_path': '/a0xs5a4QjYcTkDhxgJynQPRzOlG.jpg',
#    'roles': [{'credit_id': '5ac136120e0a260c1400c72a',
#      'character': 'Ella misma',
#      'episode_count': 2}],
#    'total_episode_count': 2,
#    'order': 115},
#   {'adult': False,
#    'gender': 0,
#    'id': 1372428,
#    'known_for_department': 'Acting',
#    'name': 'Julia Otero',
#    'original_name': 'Julia Otero',
#    'popularity': 0.6,
#    'profile_path': '/eQuiMyDKeDcfnmhAGdCzZumAfaO.jpg',
#    'roles': [{'credit_id': '5ac1306fc3a3682d3300b150',
#      'character': 'Ella misma',
#      'episode_count': 1}],
#    'total_episode_count': 1,
#    'order': 10},
#   {'adult': False,
#    'gender': 1,
#    'id': 1723075,
#    'known_for_department': 'Acting',
#    'name': 'Ainhoa Santamaría',
#    'original_name': 'Ainhoa Santamaría',
#    'popularity': 2.13,
#    'profile_path': '/rpa4VYRYCxMCGqnSz4slx6O8DkY.jpg',
#    'roles': [{'credit_id': '5ac131fc92514160180498c2',
#      'character': 'Laura Román',
#      'episode_count': 1}],
#    'total_episode_count': 1,
#    'order': 17},
#   {'adult': False,
#    'gender': 0,
#    'id': 2013151,
#    'known_for_department': 'Acting',
#    'name': 'Mercedes Pascua',
#    'original_name': 'Mercedes Pascua',
#    'popularity': 0.73,
#    'profile_path': '/v58n4SmhLzYPdjM4nFiPcSeyWey.jpg',
#    'roles': [{'credit_id': '5ac132aa0e0a260c1400c1c1',
#      'character': 'Ella misma',
#      'episode_count': 1}],
#    'total_episode_count': 1,
#    'order': 21},
#   {'adult': False,
#    'gender': 2,
#    'id': 27471,
#    'known_for_department': 'Acting',
#    'name': 'Luis Bermejo',
#    'original_name': 'Luis Bermejo',
#    'popularity': 1.023,
#    'profile_path': '/rl4hG3Ou4N244hq5eKhGLz0gIBL.jpg',
#    'roles': [{'credit_id': '5ac1332cc3a3682d3300b583',
#      'character': 'Compañero de celda de Berlín',
#      'episode_count': 1}],
#    'total_episode_count': 1,
#    'order': 22},
#   {'adult': False,
#    'gender': 0,
#    'id': 2013152,
#    'known_for_department': 'Acting',
#    'name': 'Susanna Griso',
#    'original_name': 'Susanna Griso',
#    'popularity': 1.708,
#    'profile_path': '/6JvBFgl6K4vub4BYz0MGrRzgqmN.jpg',
#    'roles': [{'credit_id': '5ac1333592514126c300b693',
#      'character': 'Ella misma',
#      'episode_count': 1}],
#    'total_episode_count': 1,
#    'order': 23},
#   {'adult': False,
#    'gender': 0,
#    'id': 2013153,
#    'known_for_department': 'Acting',
#    'name': 'Alfonso Egea',
#    'original_name': 'Alfonso Egea',
#    'popularity': 0.6,
#    'profile_path': '/acDlfBpZkEcSc9b3BF3q1NU1Dx3.jpg',
#    'roles': [{'credit_id': '5ac1333e0e0a264a5704be77',
#      'character': 'Él mismo',
#      'episode_count': 1}],
#    'total_episode_count': 1,
#    'order': 24},
#   {'adult': False,
#    'gender': 0,
#    'id': 2013154,
#    'known_for_department': 'Acting',
#    'name': 'Nacho Abad',
#    'original_name': 'Nacho Abad',
#    'popularity': 1.38,
#    'profile_path': '/aCgEd9zMiHuzRgfUdZF4OHk2kw8.jpg',
#    'roles': [{'credit_id': '5ac133480e0a260c4a00d2f3',
#      'character': 'Él mismo',
#      'episode_count': 1}],
#    'total_episode_count': 1,
#    'order': 25},
#   {'adult': False,
#    'gender': 2,
#    'id': 2365625,
#    'known_for_department': 'Acting',
#    'name': 'Jesús Gallo',
#    'original_name': 'Jesús Gallo',
#    'popularity': 0.6,
#    'profile_path': '/5Ep77vJatLLxAxYBaBpqpYE4iXj.jpg',
#    'roles': [{'credit_id': '5d31de45caab6d0b29a33b5f',
#      'character': 'Teniente Alcázar',
#      'episode_count': 1}],
#    'total_episode_count': 1,
#    'order': 49},
#   {'adult': False,
#    'gender': 1,
#    'id': 2365631,
#    'known_for_department': 'Acting',
#    'name': 'Nathalie Portela',
#    'original_name': 'Nathalie Portela',
#    'popularity': 0.6,
#    'profile_path': '/eQUiFavaOxZ7SLe8wWBfzlsqkIz.jpg',
#    'roles': [{'credit_id': '5d31e09d2f8d094522d639a7',
#      'character': 'Secretaria de Estado',
#      'episode_count': 1}],
#    'total_episode_count': 1,
#    'order': 64},
#   {'adult': False,
#    'gender': 2,
#    'id': 2138503,
#    'known_for_department': 'Acting',
#    'name': 'José de Luna',
#    'original_name': 'José de Luna',
#    'popularity': 2.075,
#    'profile_path': '/qJT2chpQAnZkZm0VDAUKYzPi7UJ.jpg',
#    'roles': [{'credit_id': '5d31e4032f8d090012d80bbc',
#      'character': 'Perico',
#      'episode_count': 1}],
#    'total_episode_count': 1,
#    'order': 69},
#   {'adult': False,
#    'gender': 2,
#    'id': 1685615,
#    'known_for_department': 'Acting',
#    'name': 'Chema del Barco',
#    'original_name': 'Chema del Barco',
#    'popularity': 0.608,
#    'profile_path': '/xDqPC3FvDZclYJnSHmmIJZ9qza7.jpg',
#    'roles': [{'credit_id': '5d31e40b6a300b5922ad59c8',
#      'character': 'Manolo',
#      'episode_count': 1}],
#    'total_episode_count': 1,
#    'order': 70},
#   {'adult': False,
#    'gender': 2,
#    'id': 26289,
#    'known_for_department': 'Acting',
#    'name': 'Juanma Lara',
#    'original_name': 'Juanma Lara',
#    'popularity': 1.124,
#    'profile_path': '/wdSbwVDFDt2SsS6nX0nyhYo5h3r.jpg',
#    'roles': [{'credit_id': '5d31e4171d78f20010e0e45a',
#      'character': 'Paco',
#      'episode_count': 1}],
#    'total_episode_count': 1,
#    'order': 71},
#   {'adult': False,
#    'gender': 2,
#    'id': 2310290,
#    'known_for_department': 'Acting',
#    'name': 'Joaquín Gómez',
#    'original_name': 'Joaquín Gómez',
#    'popularity': 0.6,
#    'profile_path': '/kBibeuuZiwdiHGT3PwJlWrDPMHn.jpg',
#    'roles': [{'credit_id': '5d31e4271d78f20010e0e484',
#      'character': 'Pedro',
#      'episode_count': 1}],
#    'total_episode_count': 1,
#    'order': 72},
#   {'adult': False,
#    'gender': 1,
#    'id': 101401,
#    'known_for_department': 'Acting',
#    'name': 'Susi Sánchez',
#    'original_name': 'Susi Sánchez',
#    'popularity': 2.622,
#    'profile_path': '/hsOZ4Hyw3Zu2GnariSg28sUixPV.jpg',
#    'roles': [{'credit_id': '5d31e55d2f8d090012d80fb6',
#      'character': 'Reni',
#      'episode_count': 1}],
#    'total_episode_count': 1,
#    'order': 74},
#   {'adult': False,
#    'gender': 2,
#    'id': 588129,
#    'known_for_department': 'Acting',
#    'name': 'Federico Pérez Rey',
#    'original_name': 'Federico Pérez Rey',
#    'popularity': 0.6,
#    'profile_path': '/gNUzohRc1a7qXVrTkkmeonLifBg.jpg',
#    'roles': [{'credit_id': '5d31e563caab6d1640a571f1',
#      'character': 'Bernardo',
#      'episode_count': 1}],
#    'total_episode_count': 1,
#    'order': 75},
#   {'adult': False,
#    'gender': 2,
#    'id': 1499043,
#    'known_for_department': 'Acting',
#    'name': 'Carlos Cabra',
#    'original_name': 'Carlos Cabra',
#    'popularity': 0.72,
#    'profile_path': '/vBpv2mKWjcEn7qUfJDt3DuQ6wcG.jpg',
#    'roles': [{'credit_id': '5d31e56c2f8d090012d80fc1',
#      'character': 'Justino',
#      'episode_count': 1}],
#    'total_episode_count': 1,
#    'order': 76},
#   {'adult': False,
#    'gender': 0,
#    'id': 1097775,
#    'known_for_department': 'Acting',
#    'name': 'Enrique Asenjo',
#    'original_name': 'Enrique Asenjo',
#    'popularity': 1.38,
#    'profile_path': '/wiOM7gboDHj9fqlIZsBSSIaEkdv.jpg',
#    'roles': [{'credit_id': '610d4726ee43e80027d28b12',
#      'character': 'Arturo',
#      'episode_count': 1}],
#    'total_episode_count': 1,
#    'order': 76},
#   {'adult': False,
#    'gender': 2,
#    'id': 2365652,
#    'known_for_department': 'Acting',
#    'name': 'Rodrigo Gibaja',
#    'original_name': 'Rodrigo Gibaja',
#    'popularity': 0.6,
#    'profile_path': None,
#    'roles': [{'credit_id': '5d31e5742f8d090012d80ff0',
#      'character': 'Axel',
#      'episode_count': 1}],
#    'total_episode_count': 1,
#    'order': 77},
#   {'adult': False,
#    'gender': 2,
#    'id': 1283839,
#    'known_for_department': 'Acting',
#    'name': 'Jaskaran Brady',
#    'original_name': 'Jaskaran Brady',
#    'popularity': 0.6,
#    'profile_path': None,
#    'roles': [{'credit_id': '610d47365a4690008049e26e',
#      'character': 'Dr. Ahmed',
#      'episode_count': 1}],
#    'total_episode_count': 1,
#    'order': 77},
#   {'adult': False,
#    'gender': 0,
#    'id': 2593779,
#    'known_for_department': 'Acting',
#    'name': 'René León',
#    'original_name': 'René León',
#    'popularity': 0.6,
#    'profile_path': None,
#    'roles': [{'credit_id': '610d47795bce9e002cfa22a5',
#      'character': 'Policía UIT',
#      'episode_count': 1}],
#    'total_episode_count': 1,
#    'order': 78},
#   {'adult': False,
#    'gender': 2,
#    'id': 1902023,
#    'known_for_department': 'Acting',
#    'name': 'Roberto Chapu',
#    'original_name': 'Roberto Chapu',
#    'popularity': 0.6,
#    'profile_path': '/nNYbmoJ6zZR0qrpKsJdKY72SjAC.jpg',
#    'roles': [{'credit_id': '5d31e57a2f8d090010d7ff2d',
#      'character': 'Ingeniero',
#      'episode_count': 1}],
#    'total_episode_count': 1,
#    'order': 78},
#   {'adult': False,
#    'gender': 1,
#    'id': 2682265,
#    'known_for_department': 'Acting',
#    'name': 'Imán Padellano',
#    'original_name': 'Imán Padellano',
#    'popularity': 0.6,
#    'profile_path': None,
#    'roles': [{'credit_id': '610d53858138310045ab5c79',
#      'character': '',
#      'episode_count': 1}],
#    'total_episode_count': 1,
#    'order': 81},
#   {'adult': False,
#    'gender': 0,
#    'id': 2278286,
#    'known_for_department': 'Acting',
#    'name': 'Toni Salgado',
#    'original_name': 'Toni Salgado',
#    'popularity': 0.6,
#    'profile_path': '/8ZqdEwtAwzjcOsslOmy4AeX4wYi.jpg',
#    'roles': [{'credit_id': '610d57a9813831002d88f776',
#      'character': 'Policía',
#      'episode_count': 1}],
#    'total_episode_count': 1,
#    'order': 92},
#   {'adult': False,
#    'gender': 1,
#    'id': 20549,
#    'known_for_department': 'Acting',
#    'name': 'Cecilia Rivera',
#    'original_name': 'Cecilia Rivera',
#    'popularity': 0.948,
#    'profile_path': None,
#    'roles': [{'credit_id': '610d589a813831002d88f9da',
#      'character': 'Sheila',
#      'episode_count': 1}],
#    'total_episode_count': 1,
#    'order': 95},
#   {'adult': False,
#    'gender': 0,
#    'id': 1610298,
#    'known_for_department': 'Acting',
#    'name': 'Gonzalo Bouza',
#    'original_name': 'Gonzalo Bouza',
#    'popularity': 0.6,
#    'profile_path': '/7doEnnzHGZXsyfBSLpYhd2oZtyz.jpg',
#    'roles': [{'credit_id': '6138e6acda9ef20090c5f3ee',
#      'character': 'Policía',
#      'episode_count': 1}],
#    'total_episode_count': 1,
#    'order': 108},
#   {'adult': False,
#    'gender': 0,
#    'id': 2003978,
#    'known_for_department': 'Acting',
#    'name': 'Pedro Freijeiro',
#    'original_name': 'Pedro Freijeiro',
#    'popularity': 0.6,
#    'profile_path': None,
#    'roles': [{'credit_id': '6138e6ba9369a200239dcdfd',
#      'character': 'Policía',
#      'episode_count': 1}],
#    'total_episode_count': 1,
#    'order': 109},
#   {'adult': False,
#    'gender': 0,
#    'id': 1396599,
#    'known_for_department': 'Acting',
#    'name': 'Maarten Dannenberg',
#    'original_name': 'Maarten Dannenberg',
#    'popularity': 0.6,
#    'profile_path': '/pvivKULDeayAAWRXaWaXRw0Vcvf.jpg',
#    'roles': [{'credit_id': '6138ebe951c01f0025f6d497',
#      'character': 'Hans',
#      'episode_count': 1}],
#    'total_episode_count': 1,
#    'order': 111},
#   {'adult': False,
#    'gender': 2,
#    'id': 3205504,
#    'known_for_department': 'Acting',
#    'name': 'Juan Carlos Heredia',
#    'original_name': 'Juan Carlos Heredia',
#    'popularity': 0.6,
#    'profile_path': None,
#    'roles': [{'credit_id': '6138ed422cde980062dd2460',
#      'character': 'Canalejas',
#      'episode_count': 1}],
#    'total_episode_count': 1,
#    'order': 112},
#   {'adult': False,
#    'gender': 1,
#    'id': 3024221,
#    'known_for_department': 'Acting',
#    'name': 'Jennifer Miranda',
#    'original_name': 'Jennifer Miranda',
#    'popularity': 0.6,
#    'profile_path': None,
#    'roles': [{'credit_id': '6138ed50091e62002cedd07a',
#      'character': 'Arteche',
#      'episode_count': 1}],
#    'total_episode_count': 1,
#    'order': 113}],
#  'crew': [{'adult': False,
#    'gender': 2,
#    'id': 1733162,
#    'known_for_department': 'Art',
#    'name': 'Abdón Alcañiz',
#    'original_name': 'Abdón Alcañiz',
#    'popularity': 0.98,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5ac128090e0a260c3900b679',
#      'job': 'Art Direction',
#      'episode_count': 31}],
#    'department': 'Art',
#    'total_episode_count': 31},
#   {'adult': False,
#    'gender': 2,
#    'id': 2013082,
#    'known_for_department': 'Art',
#    'name': 'Fernando González',
#    'original_name': 'Fernando González',
#    'popularity': 0.6,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5d31e9c12f8d095259d76f26',
#      'job': 'Production Design',
#      'episode_count': 16},
#     {'credit_id': '5ac127fe9251416015048775',
#      'job': 'Art Direction',
#      'episode_count': 15}],
#    'department': 'Art',
#    'total_episode_count': 31},
# ...
#    'original_name': 'Laia Coll',
#    'popularity': 0.6,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5d31ea11caab6d31b2a3eab5',
#      'job': 'Production Manager',
#      'episode_count': 16}],
#    'department': 'Production',
#    'total_episode_count': 16},
#   {'adult': False,
#    'gender': 0,
#    'id': 2365664,
#    'known_for_department': 'Production',
#    'name': 'Paula Moreno',
#    'original_name': 'Paula Moreno',
#    'popularity': 0.6,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5d31eab96a300b5922ad68fa',
#      'job': 'Production Assistant',
#      'episode_count': 16}],
#    'department': 'Production',
#    'total_episode_count': 16},
#   {'adult': False,
#    'gender': 0,
#    'id': 2365660,
#    'known_for_department': 'Production',
#    'name': 'Sol de la Fuente',
#    'original_name': 'Sol de la Fuente',
#    'popularity': 0.6,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5d31ea591d78f20011e0f263',
#      'job': 'Production Coordinator',
#      'episode_count': 16}],
#    'department': 'Production',
#    'total_episode_count': 16},
#   {'adult': False,
#    'gender': 0,
#    'id': 2365663,
#    'known_for_department': 'Production',
#    'name': 'Nuria Hernando',
#    'original_name': 'Nuria Hernando',
#    'popularity': 0.6,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5d31eaae1d78f2000fe0ed4f',
#      'job': 'Production Assistant',
#      'episode_count': 16}],
#    'department': 'Production',
#    'total_episode_count': 16},
#   {'adult': False,
#    'gender': 0,
#    'id': 2365665,
#    'known_for_department': 'Production',
#    'name': 'Daniel Nuñez',
#    'original_name': 'Daniel Nuñez',
#    'popularity': 0.6,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5d31eac42f8d094522d650f6',
#      'job': 'Production Assistant',
#      'episode_count': 16}],
#    'department': 'Production',
#    'total_episode_count': 16},
#   {'adult': False,
#    'gender': 0,
#    'id': 2365666,
#    'known_for_department': 'Production',
#    'name': 'Siro Giannattasio',
#    'original_name': 'Siro Giannattasio',
#    'popularity': 0.6,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5d31eacf2f8d090010d80ace',
#      'job': 'Production Assistant',
#      'episode_count': 16}],
#    'department': 'Production',
#    'total_episode_count': 16},
#   {'adult': False,
#    'gender': 0,
#    'id': 2013085,
#    'known_for_department': 'Production',
#    'name': 'Sonia Martínez',
#    'original_name': 'Sonia Martínez',
#    'popularity': 0.6,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5ac1287c0e0a260c3900b74c',
#      'job': 'Executive Producer',
#      'episode_count': 15}],
#    'department': 'Production',
#    'total_episode_count': 15},
#   {'adult': False,
#    'gender': 1,
#    'id': 1637084,
#    'known_for_department': 'Creator',
#    'name': 'Esther Martínez Lobato',
#    'original_name': 'Esther Martínez Lobato',
#    'popularity': 1.38,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5ac12891925141272000b061',
#      'job': 'Co-Executive Producer',
#      'episode_count': 15}],
#    'department': 'Production',
#    'total_episode_count': 15},
#   {'adult': False,
#    'gender': 0,
#    'id': 2013097,
#    'known_for_department': 'Production',
#    'name': 'Leticia Criado',
#    'original_name': 'Leticia Criado',
#    'popularity': 0.6,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5ac129210e0a260c2a00bb7a',
#      'job': 'Casting Assistant',
#      'episode_count': 15}],
#    'department': 'Production',
#    'total_episode_count': 15},
#   {'adult': False,
#    'gender': 0,
#    'id': 2013087,
#    'known_for_department': 'Production',
#    'name': 'Verónica Rubio',
#    'original_name': 'Verónica Rubio',
#    'popularity': 0.6,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5ac128a8c3a3682db500afbc',
#      'job': 'Production Accountant',
#      'episode_count': 15}],
#    'department': 'Production',
#    'total_episode_count': 15},
#   {'adult': False,
#    'gender': 0,
#    'id': 2013098,
#    'known_for_department': 'Production',
#    'name': 'Alicia Recuero',
#    'original_name': 'Alicia Recuero',
#    'popularity': 0.6,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5ac1292cc3a3684448050b72',
#      'job': 'Casting Assistant',
#      'episode_count': 15}],
#    'department': 'Production',
#    'total_episode_count': 15},
#   {'adult': False,
#    'gender': 0,
#    'id': 2013086,
#    'known_for_department': 'Production',
#    'name': 'Nacho Manubens',
#    'original_name': 'Nacho Manubens',
#    'popularity': 0.98,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5ac1289d92514126c300a679',
#      'job': 'Co-Executive Producer',
#      'episode_count': 15}],
#    'department': 'Production',
#    'total_episode_count': 15},
#   {'adult': False,
#    'gender': 2,
#    'id': 2013237,
#    'known_for_department': 'Production',
#    'name': 'David Mora',
#    'original_name': 'David Mora',
#    'popularity': 0.6,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5ac1452992514126be00e1c7',
#      'job': 'Location Manager',
#      'episode_count': 6}],
#    'department': 'Production',
#    'total_episode_count': 6},
#   {'adult': False,
#    'gender': 0,
#    'id': 1714782,
#    'known_for_department': 'Sound',
#    'name': 'José Ignacio Arrufat',
#    'original_name': 'José Ignacio Arrufat',
#    'popularity': 1.4,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5ac145f9c3a368443f04cbb6',
#      'job': 'Sound Mixer',
#      'episode_count': 1},
#     {'credit_id': '5d31e8b36a300b11afa2f5e5',
#      'job': 'Sound Supervisor',
#      'episode_count': 16},
#     {'credit_id': '5ac145eec3a368443f04cbaa',
#      'job': 'Sound Designer',
#      'episode_count': 1},
#     {'credit_id': '5ac126b6925141601504852f',
#      'job': 'Sound Re-Recording Mixer',
#      'episode_count': 15}],
#    'department': 'Sound',
#    'total_episode_count': 33},
#   {'adult': False,
#    'gender': 0,
#    'id': 2013069,
#    'known_for_department': 'Sound',
#    'name': 'Mikel Z. Castells',
#    'original_name': 'Mikel Z. Castells',
#    'popularity': 1.4,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5d31e8c22f8d090010d806e7',
#      'job': 'Sound Supervisor',
#      'episode_count': 16},
#     {'credit_id': '5ac126c60e0a264a5704a6e9',
#      'job': 'Sound Re-Recording Mixer',
#      'episode_count': 15},
#     {'credit_id': '5ac145e30e0a260c2a00e8e1',
#      'job': 'Sound Designer',
#      'episode_count': 1}],
#    'department': 'Sound',
#    'total_episode_count': 32},
#   {'adult': False,
#    'gender': 2,
#    'id': 2013067,
#    'known_for_department': 'Sound',
#    'name': 'Manel Santisteban',
#    'original_name': 'Manel Santisteban',
#    'popularity': 0.694,
#    'profile_path': '/1tMVCZnC5Fe70Bh2MnfQV2I4aFA.jpg',
#    'jobs': [{'credit_id': '5ac1268f0e0a260c4d00aba9',
#      'job': 'Original Music Composer',
#      'episode_count': 31}],
#    'department': 'Sound',
#    'total_episode_count': 31},
#   {'adult': False,
#    'gender': 0,
#    'id': 2013068,
#    'known_for_department': 'Sound',
#    'name': 'Iván M. Lacámara',
#    'original_name': 'Iván M. Lacámara',
#    'popularity': 0.6,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5ac126a092514126c100a279',
#      'job': 'Original Music Composer',
#      'episode_count': 31}],
#    'department': 'Sound',
#    'total_episode_count': 31},
#   {'adult': False,
#    'gender': 2,
#    'id': 1801920,
#    'known_for_department': 'Sound',
#    'name': 'Manuel Robles',
#    'original_name': 'Manuel Robles',
#    'popularity': 0.6,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5d31e89f1d78f20011e0ee3b',
#      'job': 'Sound Mixer',
#      'episode_count': 16},
#     {'credit_id': '5ac13b0c0e0a264a5704ca1c',
#      'job': 'Boom Operator',
#      'episode_count': 14}],
#    'department': 'Sound',
#    'total_episode_count': 30},
#   {'adult': False,
#    'gender': 0,
#    'id': 1546706,
#    'known_for_department': 'Sound',
#    'name': 'Nacho Arenas',
#    'original_name': 'Nacho Arenas',
#    'popularity': 0.6,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5d31ecabcaab6d1dfc994a30',
#      'job': 'Sound Mixer',
#      'episode_count': 7},
#     {'credit_id': '5ac126ab0e0a260c4d00abed',
#      'job': 'Supervising Sound Editor',
#      'episode_count': 15}],
#    'department': 'Sound',
#    'total_episode_count': 22},
#   {'adult': False,
#    'gender': 0,
#    'id': 2013121,
#    'known_for_department': 'Sound',
#    'name': 'Cecilia Krull',
#    'original_name': 'Cecilia Krull',
#    'popularity': 0.6,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5ac12a960e0a260c3900bb44',
#      'job': 'Theme Song Performance',
#      'episode_count': 15}],
#    'department': 'Sound',
#    'total_episode_count': 15},
#   {'adult': False,
#    'gender': 0,
#    'id': 2013206,
#    'known_for_department': 'Sound',
#    'name': 'Alberto Pacheco',
#    'original_name': 'Alberto Pacheco',
#    'popularity': 0.6,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5ac13b17c3a3682d1a00c678',
#      'job': 'Boom Operator',
#      'episode_count': 14},
#     {'credit_id': '5d31ebbe6a300b11afa2fd32',
#      'job': 'Sound Mixer',
#      'episode_count': 1}],
#    'department': 'Sound',
#    'total_episode_count': 15},
#   {'adult': False,
#    'gender': 0,
#    'id': 2013246,
#    'known_for_department': 'Sound',
#    'name': 'Julio Del Pino',
#    'original_name': 'Julio Del Pino',
#    'popularity': 0.6,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5ac14611c3a3682d1a00d40c',
#      'job': 'Assistant Sound Editor',
#      'episode_count': 7}],
#    'department': 'Sound',
#    'total_episode_count': 7},
#   {'adult': False,
#    'gender': 0,
#    'id': 2013245,
#    'known_for_department': 'Sound',
#    'name': 'Jamaica Ruiz',
#    'original_name': 'Jamaica Ruiz',
#    'popularity': 0.6,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5ac145d9925141601504b133',
#      'job': 'Boom Operator',
#      'episode_count': 2}],
#    'department': 'Sound',
#    'total_episode_count': 2},
#   {'adult': False,
#    'gender': 0,
#    'id': 1815999,
#    'known_for_department': 'Directing',
#    'name': 'Javier Urosas',
#    'original_name': 'Javier Urosas',
#    'popularity': 1.134,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5ac1297c92514126c300a7a2',
#      'job': 'Visual Effects Supervisor',
#      'episode_count': 15}],
#    'department': 'Visual Effects',
#    'total_episode_count': 15},
#   {'adult': False,
#    'gender': 0,
#    'id': 2013106,
#    'known_for_department': 'Visual Effects',
#    'name': 'Sergio Santos',
#    'original_name': 'Sergio Santos',
#    'popularity': 0.694,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5ac129970e0a260c1400b1e7',
#      'job': '2D Artist',
#      'episode_count': 15}],
#    'department': 'Visual Effects',
#    'total_episode_count': 15},
#   {'adult': False,
#    'gender': 0,
#    'id': 2013105,
#    'known_for_department': 'Visual Effects',
#    'name': 'Óscar Domenech',
#    'original_name': 'Óscar Domenech',
#    'popularity': 0.6,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5ac12988c3a3682d6600c7fd',
#      'job': '3D Artist',
#      'episode_count': 15}],
#    'department': 'Visual Effects',
#    'total_episode_count': 15},
#   {'adult': False,
#    'gender': 0,
#    'id': 2013107,
#    'known_for_department': 'Visual Effects',
#    'name': 'Jorge García Inclán',
#    'original_name': 'Jorge García Inclán',
#    'popularity': 0.98,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5ac129a10e0a260c1400b200',
#      'job': '2D Artist',
#      'episode_count': 15}],
#    'department': 'Visual Effects',
#    'total_episode_count': 15},
#   {'adult': False,
#    'gender': 0,
#    'id': 2013109,
#    'known_for_department': 'Visual Effects',
#    'name': 'José Carlos Palsalobre',
#    'original_name': 'José Carlos Palsalobre',
#    'popularity': 0.6,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5ac129b7c3a3682d6600c840',
#      'job': 'Visual Effects Designer',
#      'episode_count': 15}],
#    'department': 'Visual Effects',
#    'total_episode_count': 15},
#   {'adult': False,
#    'gender': 0,
#    'id': 2013108,
#    'known_for_department': 'Visual Effects',
#    'name': 'Toni Guillén',
#    'original_name': 'Toni Guillén',
#    'popularity': 0.6,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5ac129acc3a368443f04a4fa',
#      'job': '2D Artist',
#      'episode_count': 15}],
#    'department': 'Visual Effects',
#    'total_episode_count': 15},
#   {'adult': False,
#    'gender': 1,
#    'id': 1637084,
#    'known_for_department': 'Creator',
#    'name': 'Esther Martínez Lobato',
#    'original_name': 'Esther Martínez Lobato',
#    'popularity': 1.38,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5ac13a15925141272000cc34',
#      'job': 'Writer',
#      'episode_count': 17}],
#    'department': 'Writing',
#    'total_episode_count': 17},
#   {'adult': False,
#    'gender': 0,
#    'id': 2365672,
#    'known_for_department': 'Writing',
#    'name': 'Juan Salvador López',
#    'original_name': 'Juan Salvador López',
#    'popularity': 0.6,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5d31ec76caab6d0b29a35bc6',
#      'job': 'Writer',
#      'episode_count': 14}],
#    'department': 'Writing',
#    'total_episode_count': 14},
#   {'adult': False,
#    'gender': 0,
#    'id': 1165378,
#    'known_for_department': 'Writing',
#    'name': 'Luis Moya',
#    'original_name': 'Luis Moya',
#    'popularity': 0.6,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5d31ec83caab6d1dfc9949e9',
#      'job': 'Writer',
#      'episode_count': 13}],
#    'department': 'Writing',
#    'total_episode_count': 13},
#   {'adult': False,
#    'gender': 0,
#    'id': 2013215,
#    'known_for_department': 'Writing',
#    'name': 'Pablo Roa',
#    'original_name': 'Pablo Roa',
#    'popularity': 1.38,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5ac13c35c3a368443f04c08a',
#      'job': 'Writer',
#      'episode_count': 12}],
#    'department': 'Writing',
#    'total_episode_count': 12},
#   {'adult': False,
#    'gender': 0,
#    'id': 2013214,
#    'known_for_department': 'Writing',
#    'name': 'Fernando Sancristóbal',
#    'original_name': 'Fernando Sancristóbal',
#    'popularity': 0.6,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5ac13c2a0e0a264a4e0501b7',
#      'job': 'Writer',
#      'episode_count': 12}],
#    'department': 'Writing',
#    'total_episode_count': 12},
#   {'adult': False,
#    'gender': 0,
#    'id': 2013216,
#    'known_for_department': 'Writing',
#    'name': 'David Barrocal',
#    'original_name': 'David Barrocal',
#    'popularity': 0.828,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5ac13c3fc3a368443f04c09b',
#      'job': 'Writer',
#      'episode_count': 10}],
#    'department': 'Writing',
#    'total_episode_count': 10},
#   {'adult': False,
#    'gender': 0,
#    'id': 2365678,
#    'known_for_department': 'Writing',
#    'name': 'Ana Boyero',
#    'original_name': 'Ana Boyero',
#    'popularity': 0.6,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5d31ee501d78f20011e0fd96',
#      'job': 'Writer',
#      'episode_count': 8}],
#    'department': 'Writing',
#    'total_episode_count': 8},
#   {'adult': False,
#    'gender': 1,
#    'id': 1568240,
#    'known_for_department': 'Writing',
#    'name': 'Esther Morales',
#    'original_name': 'Esther Morales',
#    'popularity': 0.6,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5ac143740e0a264a5704d54d',
#      'job': 'Writer',
#      'episode_count': 7}],
#    'department': 'Writing',
#    'total_episode_count': 7},
#   {'adult': False,
#    'gender': 0,
#    'id': 1456400,
#    'known_for_department': 'Creator',
#    'name': 'Emilio Díez',
#    'original_name': 'Emilio Díez',
#    'popularity': 0.694,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5d31efe2caab6d1dfc9951fb',
#      'job': 'Writer',
#      'episode_count': 7}],
#    'department': 'Writing',
#    'total_episode_count': 7},
#   {'adult': False,
#    'gender': 0,
#    'id': 2365681,
#    'known_for_department': 'Writing',
#    'name': 'Almudena Ramirez Pantanella',
#    'original_name': 'Almudena Ramirez Pantanella',
#    'popularity': 0.6,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5d31ef602f8d095259d77ca5',
#      'job': 'Writer',
#      'episode_count': 2}],
#    'department': 'Writing',
#    'total_episode_count': 2},
#   {'adult': False,
#    'gender': 0,
#    'id': 2365673,
#    'known_for_department': 'Writing',
#    'name': 'Alberto Úcar',
#    'original_name': 'Alberto Úcar',
#    'popularity': 0.6,
#    'profile_path': None,
#    'jobs': [{'credit_id': '5d31ec8ecaab6d0b29a35c12',
#      'job': 'Writer',
#      'episode_count': 1}],
#    'department': 'Writing',
#    'total_episode_count': 1}],
#  'id': 71446}
